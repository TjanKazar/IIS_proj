# %% [markdown]
# <h3>Konfiguracija podatkovnih virov

# %%
import great_expectations as gx


context = gx.get_context()
context.sources.delete("traffic")

datasource_name = "traffic"
datasource = context.sources.add_pandas_filesystem(
    name=datasource_name,
    base_directory="../data/preprocessed"
)

batch_asset_name = "traffic_data"

data_asset = datasource.add_csv_asset(
    name=batch_asset_name,
    batching_regex="traffic.csv"
)

# %% [markdown]
# <h3>Ustvarjanje testne zbirke

# %%
expectation_suite_name = "traffic_suite"
expectation_suite = context.add_or_update_expectation_suite(expectation_suite_name="traffic_suite")

# %% [markdown]
# <h3>Samodejno ustvarjanje pričakovanj

# %%
asset = context.get_datasource(datasource_name).get_asset(batch_asset_name)

# %%
batch_request = asset.build_batch_request()
validator = context.get_validator(
    batch_request=batch_request,
    expectation_suite_name=expectation_suite_name
)

# %%
#Now run the data assistant with the validator
exclude_column_names = []
data_assistant_result = context.assistants.onboarding.run(
    validator=validator,
    exclude_column_names=exclude_column_names
)
# Out:
# ...
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
#save expectation suite
expectation_suite = data_assistant_result.get_expectation_suite()
context.save_expectation_suite(
    expectation_suite=expectation_suite,
    expectation_suite_name=expectation_suite_name)
# Out:
# '/home/tjan-kazar/storage/Faks/mag2/IIS/Projekt/iis/gx/expectations/traffic_suite.json'

# %% [markdown]
# <h3>Checkpoint creation

# %%
checkpoint_name = "traffic_checkpoint"
batch_request = asset.build_batch_request()

checkpoint = context.add_or_update_checkpoint(
    name=checkpoint_name,
    validations=[
        {
            "batch_request": batch_request,
            "expectation_suite_name": expectation_suite_name,
        }
    ],
)

# %%
# run checkpoint
checkpoint_result = checkpoint.run()

#build data docs
site = context.build_data_docs()
context.open_data_docs()
# Out:
# Calculating Metrics:   0%|          | 0/117 [00:00<?, ?it/s]

# %%
data_docs = context.build_data_docs()
# Out:
# [2] Sandbox: CanCreateUserNamespace() clone() failure: EPERM
